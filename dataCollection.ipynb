# %% [markdown]
# # 데이터 수집

# %%
# %pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (2025.1.31)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (3.10.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (2.1.1)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (11.1.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /home/an0jin/.local/lib/python3.12/site-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/an0jin/.local/lib/python3.12/site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/an0jin/.local/lib/python3.12/site-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in /home/an0jin/.local/lib/python3.12/site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/an0jin/.local/lib/python3.12/site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/an0jin/.local/lib/python3.12/site-packages (from requests->roboflow) (3.4.1)
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.6 MB/s eta 0:00:0000:0100:01
# Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 7.6 MB/s eta 0:00:0000:0100:01
# Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 31.0 MB/s eta 0:00:0000:0100:01
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 roboflow-1.2.11
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.getenv("roboflow")[::2]
# Out:
# '0OxPuV9Cje'

# %%
import os
import shutil
from roboflow import Roboflow
rf=Roboflow(api_key=os.getenv("roboflow"))
rf

# %%
links=[
    "https://universe.roboflow.com/nemesis-eg9lw/personalcolor",
    "https://universe.roboflow.com/jayshen-9iil4/facekind-6ohgo",
    "https://universe.roboflow.com/nemesis-eg9lw/pc-mx7h7"
    
]

# %% [markdown]
# ## roboflow 양식
# https://universe.roboflow.com/워크스페이스/프로젝트명

# %%
for link in links:
    linklist=link.split("/")
    version=1
    while True:
        try:
            rf.workspace(linklist[-2]).project(linklist[-1]).version(version).download("folder")
            version+=1
        except:
            try:
                rf.workspace(linklist[-2]).project(linklist[-1]).version(version).download("yolov8")
                version+=1
            except:
                break
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in personalcolor-1 to yolov8:: 100%|██████████| 147013/147013 [00:08<00:00, 17299.81it/s]
# Extracting Dataset Version Zip to personalcolor-1 in yolov8:: 100%|██████████| 5145/5145 [00:00<00:00, 15673.11it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in personalcolor-2 to yolov8:: 100%|██████████| 22306/22306 [00:02<00:00, 10351.67it/s]
# Extracting Dataset Version Zip to personalcolor-2 in yolov8:: 100%|██████████| 1235/1235 [00:00<00:00, 14877.18it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in facekind-1 to yolov8:: 100%|██████████| 39897/39897 [00:02<00:00, 17423.81it/s]
# Extracting Dataset Version Zip to facekind-1 in yolov8:: 100%|██████████| 1972/1972 [00:00<00:00, 14358.12it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in facekind-2 to yolov8:: 100%|██████████| 9315/9315 [00:01<00:00, 5790.09it/s]
# Extracting Dataset Version Zip to facekind-2 in yolov8:: 100%|██████████| 1972/1972 [00:00<00:00, 18963.04it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in facekind-3 to yolov8:: 100%|██████████| 9323/9323 [00:02<00:00, 4539.90it/s]
# Extracting Dataset Version Zip to facekind-3 in yolov8:: 100%|██████████| 1972/1972 [00:00<00:00, 15588.77it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in PC-1 to yolov8:: 100%|██████████| 24077/24077 [00:02<00:00, 9387.20it/s]
# Extracting Dataset Version Zip to PC-1 in yolov8:: 100%|██████████| 1331/1331 [00:00<00:00, 24526.69it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in PC-2 to yolov8:: 100%|██████████| 24125/24125 [00:02<00:00, 11066.45it/s]
# Extracting Dataset Version Zip to PC-2 in yolov8:: 100%|██████████| 1331/1331 [00:00<00:00, 17405.27it/s]
# loading Roboflow workspace...
# loading Roboflow project...
# loading Roboflow workspace...
# loading Roboflow project...
